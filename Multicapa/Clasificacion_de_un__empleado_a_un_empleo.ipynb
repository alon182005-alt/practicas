# %% [markdown]
# <a href="https://colab.research.google.com/github/alon182005-alt/practicas/blob/main/Multicapa/Clasificacion_de_un__empleado_a_un_empleo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Generar dataset sintético con diferentes rangos por habilidad
n_muestras = 5000
# Habilidades técnicas: 70-100
tec = np.random.randint(70, 101, (n_muestras, 6))
# Habilidades matemáticas: 60-90
mat = np.random.randint(60, 91, (n_muestras, 6))
# Habilidades psicológicas: 50-85
psi = np.random.randint(50, 86, (n_muestras, 6))
# Nombres de columnas
columnas = [
    'python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube',
    'estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado',
    'trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas'
]
# Crear DataFrame
df = pd.DataFrame(np.concatenate([tec, mat, psi], axis=1), columns=columnas)

# %%
# Calcular promedio por grupo y promedio total
prom_tecnologicas = df[['python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube']].mean(axis=1)
prom_matematicas  = df[['estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado']].mean(axis=1)
prom_psicologicas = df[['trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas']].mean(axis=1)
# Promedio total = promedio de los 3 promedios
prom_total = (prom_tecnologicas + prom_matematicas + prom_psicologicas) / 3
# Etiqueta: 1 = apto si promedio total > 80
y = (prom_total > 75).astype(int)
# one-hot encoding
y = pd.get_dummies(y).values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
)

# Escalamiento
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
modelo = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

adam = Adam(learning_rate=0.001)
modelo.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#entrenamiento
history = modelo.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7739 - loss: 0.4333 - val_accuracy: 0.9650 - val_loss: 0.0939
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9681 - loss: 0.0853 - val_accuracy: 0.9590 - val_loss: 0.1045
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9825 - loss: 0.0518 - val_accuracy: 0.9840 - val_loss: 0.0467
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9906 - loss: 0.0333 - val_accuracy: 0.9760 - val_loss: 0.0496
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9915 - loss: 0.0236 - val_accuracy: 0.9850 - val_loss: 0.0394
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9895 - loss: 0.0226 - val_accuracy: 0.9830 - val_loss: 0.0460
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9863 - loss: 0.0331 - val_accuracy: 0.9730 - val_loss: 0.0624
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9926 - loss: 0.0239 - val_accuracy: 0.9850 - val_loss: 0.0365
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9973 - loss: 0.0080 - val_accuracy: 0.9820 - val_loss: 0.0561
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9953 - loss: 0.0131 - val_accuracy: 0.9840 - val_loss: 0.0585
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9895 - loss: 0.0229 - val_accuracy: 0.9830 - val_loss: 0.0474
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9978 - loss: 0.0084 - val_accuracy: 0.9740 - val_loss: 0.0808
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9924 - loss: 0.0213 - val_accuracy: 0.9760 - val_loss: 0.0692
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9981 - loss: 0.0067 - val_accuracy: 0.9750 - val_loss: 0.0700
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9750 - val_loss: 0.1133
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9941 - loss: 0.0187 - val_accuracy: 0.9820 - val_loss: 0.0649
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9953 - loss: 0.0123 - val_accuracy: 0.9800 - val_loss: 0.0686
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9944 - loss: 0.0129 - val_accuracy: 0.9770 - val_loss: 0.0796
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 0.9760 - val_loss: 0.0943
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9997 - loss: 0.0019 - val_accuracy: 0.9800 - val_loss: 0.0750
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9770 - val_loss: 0.1256
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9922 - loss: 0.0196 - val_accuracy: 0.9840 - val_loss: 0.0704
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 0.0029 - val_accuracy: 0.9820 - val_loss: 0.0608
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9961 - loss: 0.0112 - val_accuracy: 0.9750 - val_loss: 0.0796
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 0.0036 - val_accuracy: 0.9840 - val_loss: 0.0565
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.3625e-04 - val_accuracy: 0.9850 - val_loss: 0.0541
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.1694e-04 - val_accuracy: 0.9850 - val_loss: 0.0554
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.3602e-04 - val_accuracy: 0.9850 - val_loss: 0.0575
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.1820e-04 - val_accuracy: 0.9850 - val_loss: 0.0597
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.9146e-05 - val_accuracy: 0.9850 - val_loss: 0.0612
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 3.9473e-05 - val_accuracy: 0.9860 - val_loss: 0.0617
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.9980e-05 - val_accuracy: 0.9850 - val_loss: 0.0630
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.7187e-05 - val_accuracy: 0.9850 - val_loss: 0.0651
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.2874e-05 - val_accuracy: 0.9850 - val_loss: 0.0662
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.0352e-05 - val_accuracy: 0.9850 - val_loss: 0.0675
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.8936e-06 - val_accuracy: 0.9850 - val_loss: 0.0700
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.7195e-06 - val_accuracy: 0.9850 - val_loss: 0.0699
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 3.9687e-06 - val_accuracy: 0.9850 - val_loss: 0.0722
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.9633e-06 - val_accuracy: 0.9850 - val_loss: 0.0729
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.8499e-06 - val_accuracy: 0.9850 - val_loss: 0.0741
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.4282e-06 - val_accuracy: 0.9850 - val_loss: 0.0772
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2830e-06 - val_accuracy: 0.9850 - val_loss: 0.0783
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 7.6946e-07 - val_accuracy: 0.9840 - val_loss: 0.0804
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.6990e-07 - val_accuracy: 0.9850 - val_loss: 0.0802
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.6630e-07 - val_accuracy: 0.9850 - val_loss: 0.0820
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 3.1373e-07 - val_accuracy: 0.9840 - val_loss: 0.0843
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 3.0793e-07 - val_accuracy: 0.9840 - val_loss: 0.0856
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 1.0000 - loss: 2.3282e-07 - val_accuracy: 0.9840 - val_loss: 0.0868
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.5291e-07 - val_accuracy: 0.9840 - val_loss: 0.0882
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.0997e-07 - val_accuracy: 0.9840 - val_loss: 0.0884

# %%
#evaluacion
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Evolución de la función de pérdida')
plt.show()

loss, acc = modelo.evaluate(X_test, y_test)
print(f"\n🔹 Loss: {loss:.4f}  |  Accuracy: {acc:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0603
#
# 🔹 Loss: 0.0884  |  Accuracy: 0.9840

# %%
#matriz de confusion
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score

pred = modelo.predict(X_test)
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Apto', 'Apto'])
disp.plot(cmap='Blues')
plt.show()

sensitivity = recall_score(y_true, y_pred, average=None)
print("\nSensitivity (Recall) por clase:")
print(f"No Apto: {sensitivity[0]:.2f}")
print(f"Apto: {sensitivity[1]:.2f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Sensitivity (Recall) por clase:
# No Apto: 0.98
# Apto: 0.98

# %%
nuevo_candidato = np.array([[90, 88, 85, 87, 84, 89,   # técnicas
                             82, 86, 85, 83, 87, 80,   # matemáticas
                             70, 75, 80, 72, 78, 74]]) # psicológicas

nuevo_candidato_scaled = scaler.transform(nuevo_candidato)
pred_nuevo = modelo.predict(nuevo_candidato_scaled)
clase_predicha = np.argmax(pred_nuevo)

print("Evaluación de nuevo candidato:")
print(f"Resultado: {'Apto' if clase_predicha == 1 else 'No Apto'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Evaluación de nuevo candidato:
# Resultado: Apto
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
